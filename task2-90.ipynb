# %%
import cv2
import numpy as np
import pandas as pd
import os
import sys
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import shutil
from os import path
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image_dataset_from_directory
from keras.preprocessing.image import ImageDataGenerator

import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)

import warnings
warnings.filterwarnings('always')

# %% [markdown]
# # Utils Functions

# %%
def continueTrain_model(model3,model4, meta, batch_data, y):
    # Training model 4
    # model4.fit(batch_data, y, validation_data=(x_val,y_val), epochs=1, batch_size= 256)
    
    # Training meta-model
    train_meta(model3,model4,meta,batch_data, y, epochs=2)

    # Re-evaluate
    meta_pred = model_predict(model3,model4, meta,x_test)
    multiclass_classification_report(y_test,meta_pred)

def train_meta(model3,model4,meta,x, y, epochs):
    batchpred4 = model4.predict(x)
    batchpred3 = model3.predict(x)
    stacked_train = np.concatenate((batchpred3, batchpred4), axis=1)

    batchpred4 = model4.predict(x_val)
    batchpred3 = model3.predict(x_val)
    stacked_val = np.concatenate((batchpred3, batchpred4), axis=1)
    meta.fit(stacked_train, y, validation_data=(stacked_val, y_val), epochs=epochs, batch_size=256)
    return meta
    
def model_predict(model3,model4, meta,x):
    pred3 = model3.predict(x)
    pred4 = model4.predict(x)

    stacked = np.concatenate((pred3, pred4), axis=1)
    meta_pred = meta.predict(stacked)
    return meta_pred

def multiclass_classification_report(y_test, prediction):
    """
        Method to generate sklearn classification report with CNN multiclass output
    """
    encoded_pred = encode_pred(prediction)
    print(classification_report(y_test, encoded_pred))

def encode_pred(prediction):
    encoded_pred = list()
    # convert each CNN output (sparse categorial) to class
    for pred in prediction:
        encoded_pred.append(np.argmax(pred))

    return np.array(encoded_pred)

# %% [markdown]
# # Load Images

# %%
# method get data for multiclass task (task 2)
def celltype_classify_data(class_list, root):    
    images = list()
    labels = list()
    
    for i, label in enumerate(class_list):
        # get image directory
        img_dir = os.path.join(root, f"{label}")
        
        for img in os.listdir(img_dir):
            img = cv2.imread(os.path.join(img_dir, img))
            # resize to 0-1 for faster computation
            resized = img / 255
            images.append(resized)
            labels.append(i)
        
    return (images, labels)

# %% [markdown]
# # Model definitions

# %%
def get_multiclass_model():
    model = tf.keras.Sequential()
    # First convo-pooling
    # Convolutional layers (filter the image with a kernel)
    model.add(tf.keras.layers.Conv2D(64, (3, 3), strides=1,activation="relu", input_shape=[27, 27, 3]))
    # Max-pooling layers (reduce the size of the image by choosing max pixel at certain area)
    model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2), strides=1))
    
    # Second convo-pooling
    # Convolutional layers (filter the image with a kernel)
    model.add(tf.keras.layers.Conv2D(64, (3, 3),strides=1, activation="relu"))
    # Max-pooling layers (reduce the size of the image by choosing max pixel at certain area)
    model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2),strides=1))
    
    # Flatten input
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(256, activation="relu"))
    model.add(tf.keras.layers.Dense(128, activation="relu"))
    model.add(tf.keras.layers.Dense(32, activation="relu"))
    # Output layer
    model.add(tf.keras.layers.Dense(4, activation="softmax"))
    # Compile model 
    model.compile(optimizer="adam",
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])
    
    return model

def get_subclass_model():
    model = tf.keras.Sequential()
    # First convo-pooling
    # Convolutional layers (filter the image with a kernel)
    model.add(tf.keras.layers.Conv2D(64, (3, 3), activation="relu", input_shape=[27, 27, 3]))
    # Max-pooling layers (reduce the size of the image by choosing max pixel at certain area)
    model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
    # Flatten input
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(256, activation="relu"))
    model.add(tf.keras.layers.Dense(128, activation="relu"))
    model.add(tf.keras.layers.Dense(32, activation="relu"))
    # Output layer
    model.add(tf.keras.layers.Dense(3, activation="softmax"))
    # Compile model 
    model.compile(optimizer="adam",
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])
    
    return model

def get_transfer_model():
    model = tf.keras.Sequential()
    # Flatten input
    model.add(tf.keras.layers.Flatten())
    # Hidden layers
    model.add(tf.keras.layers.Dense(256, activation="relu"))
    model.add(tf.keras.layers.Dense(128, activation="softmax"))
    model.add(tf.keras.layers.Dense(32, activation="relu"))
    model.add(tf.keras.layers.Dense(3, activation="sigmoid"))
    # Output layer
    model.add(tf.keras.layers.Dense(4, activation="softmax"))
    # Compile model
    model.compile(optimizer="adam",
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])
    return model

# %% [markdown]
# # Train model

# %%
image_train, label_train = celltype_classify_data(all_class, root="Image_classification_data/split3-multi-task/train")
image_val, label_val = celltype_classify_data(all_class, root="Image_classification_data/split3-multi-task/val")
image_test, label_test = celltype_classify_data(all_class, root="Image_classification_data/split3-multi-task/test")

x_train, y_train = np.array(image_train), np.array(label_train)
x_val, y_val = np.array(image_val), np.array(label_val)
x_test, y_test = np.array(image_test), np.array(label_test)

# %%
classes3 = ["epithelial", "fibroblast", "inflammatory"]
image_train, label_train = celltype_classify_data(classes3, root="Image_classification_data/split3-multi-task/train")
x3_train, y3_train = np.array(image_train), np.array(label_train)
image_val, label_val = celltype_classify_data(classes3, root="Image_classification_data/split3-multi-task/val")
x3_val, y3_val = np.array(image_val), np.array(label_val)

# %% [markdown]
# ## Train model of 3 classes

# %%
model3 = get_subclass_model()
model3.fit(x3_train, y3_train, validation_data=(x3_val, y3_val), epochs=15, batch_size=128)
# Out:
# Epoch 1/15
# 40/40 [==============================] - 4s 79ms/step - loss: 0.9119 - accuracy: 0.5903 - val_loss: 0.6747 - val_accuracy: 0.6982
# Epoch 2/15
# 40/40 [==============================] - 3s 84ms/step - loss: 0.6197 - accuracy: 0.7486 - val_loss: 0.5980 - val_accuracy: 0.7453
# Epoch 3/15
# 40/40 [==============================] - 3s 80ms/step - loss: 0.5436 - accuracy: 0.7829 - val_loss: 0.6059 - val_accuracy: 0.7365
# Epoch 4/15
# 40/40 [==============================] - 3s 78ms/step - loss: 0.5014 - accuracy: 0.8033 - val_loss: 0.5026 - val_accuracy: 0.8035
# Epoch 5/15
# 40/40 [==============================] - 3s 86ms/step - loss: 0.4685 - accuracy: 0.8129 - val_loss: 0.4688 - val_accuracy: 0.8212
# Epoch 6/15
# 40/40 [==============================] - 3s 83ms/step - loss: 0.4441 - accuracy: 0.8266 - val_loss: 0.5327 - val_accuracy: 0.7829
# Epoch 7/15
# 40/40 [==============================] - 3s 81ms/step - loss: 0.4527 - accuracy: 0.8194 - val_loss: 0.4852 - val_accuracy: 0.8076
# Epoch 8/15
# 40/40 [==============================] - 4s 103ms/step - loss: 0.4666 - accuracy: 0.8117 - val_loss: 0.4822 - val_accuracy: 0.8094
# Epoch 9/15
# 40/40 [==============================] - 4s 90ms/step - loss: 0.4223 - accuracy: 0.8372 - val_loss: 0.4686 - val_accuracy: 0.8135
# Epoch 10/15
# 40/40 [==============================] - 3s 82ms/step - loss: 0.3987 - accuracy: 0.8484 - val_loss: 0.4560 - val_accuracy: 0.8253
# Epoch 11/15
# 40/40 [==============================] - 4s 94ms/step - loss: 0.3822 - accuracy: 0.8533 - val_loss: 0.4453 - val_accuracy: 0.8300
# Epoch 12/15
# 40/40 [==============================] - 3s 84ms/step - loss: 0.3830 - accuracy: 0.8546 - val_loss: 0.4740 - val_accuracy: 0.8165
# Epoch 13/15
# 40/40 [==============================] - 3s 81ms/step - loss: 0.
# 93/93 [==============================] - 27s 289ms/step - loss: 0.4615 - accuracy: 0.8254 - val_loss: 0.7318 - val_accuracy: 0.7370
# Epoch 19/20
# 93/93 [==============================] - 23s 249ms/step - loss: 0.4263 - accuracy: 0.8359 - val_loss: 0.7649 - val_accuracy: 0.7370
# Epoch 20/20
# 93/93 [==============================] - 23s 247ms/step - loss: 0.3852 - accuracy: 0.8537 - val_loss: 0.8839 - val_accuracy: 0.7178

# %% [markdown]
# ## Train Meta-model

# %%
meta  = get_transfer_model()
x = x_train
batchpred4 = model4.predict(x)
batchpred3 = model3.predict(x)
stacked_train = np.concatenate((batchpred3, batchpred4), axis=1)

batchpred4 = model4.predict(x_val)
batchpred3 = model3.predict(x_val)
stacked_val = np.concatenate((batchpred3, batchpred4), axis=1)
meta.fit(stacked_train, y_train, validation_data=(stacked_val, y_val), epochs=100, batch_size=256)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 12ms/step - loss: 1.6482 - accuracy: 0.1400 - val_loss: 1.6116 - val_accuracy: 0.1401
# Epoch 2/100
# 24/24 [==============================] - 0s 6ms/step - loss: 1.5805 - accuracy: 0.1400 - val_loss: 1.5428 - val_accuracy: 0.1401
# Epoch 3/100
# 24/24 [==============================] - 0s 5ms/step - loss: 1.5093 - accuracy: 0.1400 - val_loss: 1.4703 - val_accuracy: 0.1401
# Epoch 4/100
# 24/24 [==============================] - 0s 7ms/step - loss: 1.4389 - accuracy: 0.1400 - val_loss: 1.4040 - val_accuracy: 0.1401
# Epoch 5/100
# 24/24 [==============================] - 0s 5ms/step - loss: 1.3762 - accuracy: 0.1400 - val_loss: 1.3428 - val_accuracy: 0.1401
# Epoch 6/100
# 24/24 [==============================] - 0s 5ms/step - loss: 1.3159 - accuracy: 0.2283 - val_loss: 1.2840 - val_accuracy: 0.2974
# Epoch 7/100
# 24/24 [==============================] - 0s 5ms/step - loss: 1.2577 - accuracy: 0.2974 - val_loss: 1.2269 - val_accuracy: 0.2999
# Epoch 8/100
# 24/24 [==============================] - 0s 5ms/step - loss: 1.2012 - accuracy: 0.3501 - val_loss: 1.1726 - val_accuracy: 0.4846
# Epoch 9/100
# 24/24 [==============================] - 0s 5ms/step - loss: 1.1485 - accuracy: 0.8209 - val_loss: 1.1218 - val_accuracy: 0.8897
# Epoch 10/100
# 24/24 [==============================] - 0s 5ms/step - loss: 1.1006 - accuracy: 0.8955 - val_loss: 1.0766 - val_accuracy: 0.8918
# Epoch 11/100
# 24/24 [==============================] - 0s 5ms/step - loss: 1.0578 - accuracy: 0.8964 - val_loss: 1.0363 - val_accuracy: 0.8923
# Epoch 12/100
# 24/24 [==============================] - 0s 5ms/step - loss: 1.0185 - accuracy: 0.8987 - val_loss: 0.9998 - val_accuracy: 0.8918
# Epoch 13/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.9818 - accuracy: 0.8955 - val_loss: 0.9629 - val_accuracy: 0.8958
# Epoch 14/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.9477 - accuracy: 0.8962 - val_loss: 0.9287 - val_accuracy: 0.8948
# Epoch 15/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.9154 - accuracy: 0.9001 - val_loss: 0.8973 - val_accuracy: 0.9004
# Epoch 16/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.8851 - accuracy: 0.8979 - val_loss: 0.8681 - val_accuracy: 0.9029
# Epoch 17/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.8584 - accuracy: 0.8967 - val_loss: 0.8433 - val_accuracy: 0.8998
# Epoch 18/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.8344 - accuracy: 0.9008 - val_loss: 0.8217 - val_accuracy: 0.8988
# Epoch 19/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.8120 - accuracy: 0.9004 - val_loss: 0.8000 - val_accuracy: 0.8998
# Epoch 20/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7924 - accuracy: 0.9013 - val_loss: 0.7815 - val_accuracy: 0.8998
# Epoch 21/100
# 24/24 [==============================] - 0s 11ms/step - loss: 0.7736 - accuracy: 0.9014 - val_loss: 0.7643 - val_accuracy: 0.8983
# Epoch 22/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.
100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4307 - accuracy: 0.9040 - val_loss: 0.4259 - val_accuracy: 0.9024
# Epoch 87/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4293 - accuracy: 0.9035 - val_loss: 0.4281 - val_accuracy: 0.9029
# Epoch 88/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4277 - accuracy: 0.9031 - val_loss: 0.4287 - val_accuracy: 0.9029
# Epoch 89/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.4256 - accuracy: 0.9045 - val_loss: 0.4225 - val_accuracy: 0.9049
# Epoch 90/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.4240 - accuracy: 0.9028 - val_loss: 0.4222 - val_accuracy: 0.9019
# Epoch 91/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4212 - accuracy: 0.9029 - val_loss: 0.4182 - val_accuracy: 0.9039
# Epoch 92/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4202 - accuracy: 0.9024 - val_loss: 0.4218 - val_accuracy: 0.9034
# Epoch 93/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4173 - accuracy: 0.9033 - val_loss: 0.4164 - val_accuracy: 0.9024
# Epoch 94/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4150 - accuracy: 0.9026 - val_loss: 0.4167 - val_accuracy: 0.9034
# Epoch 95/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4138 - accuracy: 0.9026 - val_loss: 0.4129 - val_accuracy: 0.9044
# Epoch 96/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4122 - accuracy: 0.9029 - val_loss: 0.4128 - val_accuracy: 0.9029
# Epoch 97/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4110 - accuracy: 0.9023 - val_loss: 0.4144 - val_accuracy: 0.9039
# Epoch 98/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4086 - accuracy: 0.9021 - val_loss: 0.4101 - val_accuracy: 0.9039
# Epoch 99/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4076 - accuracy: 0.9019 - val_loss: 0.4102 - val_accuracy: 0.9034
# Epoch 100/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4074 - accuracy: 0.9018 - val_loss: 0.4095 - val_accuracy: 0.9029

# %%
model3.save("results/models/model3")
model4.save("results/models/model4")
meta.save("results/models/meta")

# %% [markdown]
# # Load models

# %%
model3 = tf.keras.models.load_model("results/models/model3")
model4 = tf.keras.models.load_model("results/models/model4")
meta = tf.keras.models.load_model("results/models/meta")

# %% [markdown]
# ## Evaluate model with the test dataset

# %%
pred_test = model_predict(model3,model4,meta,x_test)
multiclass_classification_report(y_test, pred_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       817
#            1       0.89      0.87      0.88       379
#            2       0.86      0.93      0.89       510
#            3       0.79      0.64      0.70       278
#
#     accuracy                           0.89      1984
#    macro avg       0.87      0.85      0.86      1984
# weighted avg       0.89      0.89      0.89      1984

# %% [markdown]
# # Extra data

# %%
import pandas as pd

# Load Extra data
extra1_x , label1 = celltype_classify_data(["1"], root="Image_classification_data/extra")
extra0_x, label0 = celltype_classify_data(["0"], root="Image_classification_data/extra")

extra1_x = np.array(extra1_x)
extra0_x = np.array(extra0_x)
label1 = np.array(label1)
label0 = np.array(label0)

# %%
print(extra1_x.shape)
print(extra0_x.shape)
# Out:
# (2990, 27, 27, 3)
# (7394, 27, 27, 3)

# %% [markdown]
# ## Train model with extra data in batches

# %%
datagen = ImageDataGenerator()
batches = 0
batch_size = 1024
tf.config.run_functions_eagerly(False)

for x_batch in datagen.flow(extra0_x, batch_size=batch_size):
    batches += 1
    if batches >= len(extra0_x) / batch_size:
    # if batches >= 4:
        break
    else:
        print(batches)
        pred_extra0 = model_predict(model3, model4, meta,x_batch) # meta learner predict label of extra data
        pred_extra0 = encode_pred(pred_extra0) # encode probability predction into labels
        continueTrain_model(model3, model4, meta,x_batch, pred_extra0) # retrain the models with this extra data and it's given labels
# Out:
# 1
# Epoch 1/2
# 4/4 [==============================] - 1s 66ms/step - loss: 0.2692 - accuracy: 0.9971 - val_loss: 0.4120 - val_accuracy: 0.9044
# Epoch 2/2
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2385 - accuracy: 0.9902 - val_loss: 0.4143 - val_accuracy: 0.9049
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       817
#            1       0.88      0.89      0.89       379
#            2       0.87      0.92      0.89       510
#            3       0.82      0.63      0.71       278
#
#     accuracy                           0.90      1984
#    macro avg       0.88      0.85      0.86      1984
# weighted avg       0.89      0.90      0.89      1984
#
# 2
# Epoch 1/2
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2093 - accuracy: 0.9990 - val_loss: 0.4158 - val_accuracy: 0.9054
# Epoch 2/2
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1976 - accuracy: 0.9971 - val_loss: 0.4187 - val_accuracy: 0.9049
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       817
#            1       0.87      0.90      0.89       379
#            2       0.87      0.92      0.89       510
#            3       0.83      0.62      0.71       278
#
#     accuracy                           0.90      1984
#    macro avg       0.88      0.85      0.86      1984
# weighted avg       0.89      0.90      0.89      1984
#
# 3
# Epoch 1/2
# 4/4 [==============================] - 0s 27ms/step - loss: 0.1906 - accuracy: 0.9961 - val_loss: 0.4219 - val_accuracy: 0.9039
# Epoch 2/2
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1847 - accuracy: 0.9961 - val_loss: 0.4233 - val_accuracy: 0.9034
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       817
#            1       0.87      0.90      0.89       379
#            2       0.86      0.93      0.89       510
#            3       0.84      0.61      0.71       278
#
#     accuracy                           0.90      1984
#    macro avg       0.88      0.85      0.86      1984
# weighted avg       0.90      0.90      0.89      1984
#
# 4
# Epoch 1/2
# 4/4 [==============================] - 0s 29ms/step - loss: 0.1776 - accuracy: 0.9990 - val_loss: 0.4257 - val_accuracy: 0.9024
# Epoch 2/2
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1746 - accuracy: 0.9980 - val_loss: 0.4279 - val_accuracy: 0.9014
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       817
#            1       0.87      0.90      0.89       379
#            2       0.86      0.93      0.89       510
#            3       0.84      0.60      0.70       278
#
#     accuracy                           0.90      1984
#    macro avg       0.88      0.85      0.86      1984
# weighted avg       0.89      0.90      0.89      1984
#
# 5
# Epoch 1/2
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1779 - accuracy: 0.9980 - val_loss: 0.4307 - val_accuracy: 0.9009
# Epoch 2/2
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1743 - accuracy: 0.9980 - val_loss: 0.4329 - val_accuracy: 0.9004
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       817
#            1       0.87      0.90      0.88       379
#            2       0.86      0.93      0.89       510
#            3       0.84      0.60      0.70       278
#
#     accuracy                           0.90      1984
#    macro avg       0.88      0.85      0.86      1984
# weighted avg       0.89      0.90      0.89      1984
#
# 6
# Epoch 1/2
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1724 - accuracy: 0.9980 - val_loss: 0.4345 - val_accuracy: 0.8998
# Epoch 2/2
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1697 - accuracy: 0.9980 - val_loss: 0.4365 - val_accuracy: 0.8978
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       817
#            1       0.86      0.91      0.88       379
#            2       0.85      0.93      0.89       510
#            3       0.85      0.55      0.67       278
#
#     accuracy                           0.89      1984
#    macro avg       0.88      0.84      0.85      1984
# weighted avg       0.89      0.89      0.89      1984
#
# 7
# Epoch 1/2
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1656 - accuracy: 1.0000 - val_loss: 0.4379 - val_accuracy: 0.8978
# Epoch 2/2
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1636 - accuracy: 1.0000 - val_loss: 0.4397 - val_accuracy: 0.8968
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       817
#            1       0.86      0.92      0.89       379
#            2       0.85      0.93      0.89       510
#            3       0.86      0.54      0.66       278
#
#     accuracy                           0.89      1984
#    macro avg       0.88      0.84      0.85      1984
# weighted avg       0.89      0.89      0.88      1984
